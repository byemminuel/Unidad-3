# %%
import pandas as pd
brainFile = 'BrainSizeData.csv'
brainFrame = pd.read_csv(brainFile)

# %%
brainFrame.head()
# Out:
#    Gender   FSIQ    VIQ    PIQ  Weight  Height  MRI_Count  Unnamed: 7  \
# 0  Female  133.0  132.0  124.0   118.0    64.5   816932.0         NaN
# 1    Male  140.0  150.0  124.0     NaN    72.5  1001121.0         NaN
# 2    Male  139.0  123.0  150.0   143.0    73.3  1038437.0         NaN
# 3    Male  133.0  129.0  128.0   172.0    68.8   965353.0         NaN
# 4  Female  137.0  132.0  134.0   147.0    65.0   951545.0         NaN
#
#    Promedio        MRI  Unnamed: 10  Unnamed: 11
# 0     130.0   816932.0          NaN          NaN
# 1     138.0  1001121.0          NaN          NaN
# 2     137.0  1038437.0          NaN          NaN
# 3     130.0   965353.0          NaN          NaN
# 4     134.0   951545.0          NaN          NaN

# %%
brainFrame.describe()
# Out:
#              FSIQ         VIQ        PIQ      Weight     Height     MRI_Count  \
# count   40.000000   41.000000   40.00000   38.000000  39.000000  4.000000e+01
# mean   113.450000  109.618889  111.02500  151.052632  68.525641  9.087550e+05
# std     24.082071   29.147816   22.47105   23.478509   3.994649  7.228205e+04
# min     77.000000    0.374442   72.00000  106.000000  62.000000  7.906190e+05
# 25%     89.750000   90.000000   88.25000  135.250000  66.000000  8.559185e+05
# 50%    116.500000  112.000000  115.00000  146.500000  68.000000  9.053990e+05
# 75%    135.500000  129.000000  128.00000  172.000000  70.500000  9.500780e+05
# max    144.000000  150.000000  150.00000  192.000000  77.000000  1.079549e+06
#
#        Unnamed: 7    Promedio           MRI  Unnamed: 10  Unnamed: 11
# count         0.0   41.000000  4.100000e+01     1.000000     1.000000
# mean          NaN  109.520918  8.865903e+05     0.386817     0.360645
# std           NaN   28.262182  1.588597e+05          NaN          NaN
# min           NaN    0.357641  3.374780e-01     0.386817     0.360645
# 25%           NaN   90.000000  8.542580e+05     0.386817     0.360645
# 50%           NaN  103.000000  9.048580e+05     0.386817     0.360645
# 75%           NaN  133.000000  9.495890e+05     0.386817     0.360645
# max           NaN  142.000000  1.079549e+06     0.386817     0.360645

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
menDf = brainFrame[(brainFrame.Gender == 'Male')]
womenDf = brainFrame[(brainFrame.Gender == 'Female')]

# %%
# %matplotlib inline
menMeanSmarts = menDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(menMeanSmarts, menDf["MRI_Count"])
plt.show()

# %%
# %matplotlib inline
womenMeanSmarts = womenDf[["PIQ", "FSIQ", "VIQ"]].mean(axis=1)
plt.scatter(womenMeanSmarts, womenDf['MRI_Count'])
plt.show()

# %%
brainFrame.corr(method='pearson')
# Out:
#                  FSIQ       VIQ       PIQ    Weight    Height  MRI_Count  \
# FSIQ         1.000000  0.946639  0.934125 -0.051483 -0.086002   0.357641
# VIQ          0.946639  1.000000  0.778135 -0.076088 -0.071068   0.337478
# PIQ          0.934125  0.778135  1.000000  0.002512 -0.076723   0.386817
# Weight      -0.051483 -0.076088  0.002512  1.000000  0.699614   0.513378
# Height      -0.086002 -0.071068 -0.076723  0.699614  1.000000   0.601712
# MRI_Count    0.357641  0.337478  0.386817  0.513378  0.601712   1.000000
# Unnamed: 7        NaN       NaN       NaN       NaN       NaN        NaN
# Promedio     0.998859  0.947328  0.937584 -0.042403 -0.079329   0.374544
# MRI          0.357641  0.337478  0.386817  0.513378  0.601712   1.000000
# Unnamed: 10       NaN       NaN       NaN       NaN       NaN        NaN
# Unnamed: 11       NaN       NaN       NaN       NaN       NaN        NaN
#
#              Unnamed: 7  Promedio       MRI  Unnamed: 10  Unnamed: 11
# FSIQ                NaN  0.998859  0.357641          NaN          NaN
# VIQ                 NaN  0.947328  0.337478          NaN          NaN
# PIQ                 NaN  0.937584  0.386817          NaN          NaN
# Weight              NaN -0.042403  0.513378          NaN          NaN
# Height              NaN -0.079329  0.601712          NaN          NaN
# MRI_Count           NaN  0.374544  1.000000          NaN          NaN
# Unnamed: 7          NaN       NaN       NaN          NaN          NaN
# Promedio            NaN  1.000000  0.684642          NaN          NaN
# MRI                 NaN  0.684642  1.000000          NaN          NaN
# Unnamed: 10         NaN       NaN       NaN          NaN          NaN
# Unnamed: 11         NaN       NaN       NaN          NaN          NaN

# %%
womenDf.corr(method='pearson')
# Out:
#                  FSIQ       VIQ       PIQ    Weight    Height  MRI_Count  \
# FSIQ         1.000000  0.955717  0.939382  0.038192 -0.059011   0.325697
# VIQ          0.955717  1.000000  0.802652 -0.021889 -0.146453   0.254933
# PIQ          0.939382  0.802652  1.000000  0.113901 -0.001242   0.396157
# Weight       0.038192 -0.021889  0.113901  1.000000  0.552357   0.446271
# Height      -0.059011 -0.146453 -0.001242  0.552357  1.000000   0.174541
# MRI_Count    0.325697  0.254933  0.396157  0.446271  0.174541   1.000000
# Unnamed: 7        NaN       NaN       NaN       NaN       NaN        NaN
# Promedio     0.999072  0.951318  0.946876  0.045848 -0.067257   0.334868
# MRI          0.325697  0.254933  0.396157  0.446271  0.174541   1.000000
# Unnamed: 10       NaN       NaN       NaN       NaN       NaN        NaN
# Unnamed: 11       NaN       NaN       NaN       NaN       NaN        NaN
#
#              Unnamed: 7  Promedio       MRI  Unnamed: 10  Unnamed: 11
# FSIQ                NaN  0.999072  0.325697          NaN          NaN
# VIQ                 NaN  0.951318  0.254933          NaN          NaN
# PIQ                 NaN  0.946876  0.396157          NaN          NaN
# Weight              NaN  0.045848  0.446271          NaN          NaN
# Height              NaN -0.067257  0.174541          NaN          NaN
# MRI_Count           NaN  0.334868  1.000000          NaN          NaN
# Unnamed: 7          NaN       NaN       NaN          NaN          NaN
# Promedio            NaN  1.000000  0.334868          NaN          NaN
# MRI                 NaN  0.334868  1.000000          NaN          NaN
# Unnamed: 10         NaN       NaN       NaN          NaN          NaN
# Unnamed: 11         NaN       NaN       NaN          NaN          NaN

# %%
menDf.corr(method='pearson')
# Out:
#                  FSIQ       VIQ       PIQ    Weight    Height  MRI_Count  \
# FSIQ         1.000000  0.944400  0.930694 -0.278140 -0.356110   0.498369
# VIQ          0.944400  1.000000  0.766021 -0.350453 -0.355588   0.413105
# PIQ          0.930694  0.766021  1.000000 -0.156863 -0.287676   0.568237
# Weight      -0.278140 -0.350453 -0.156863  1.000000  0.406542  -0.076875
# Height      -0.356110 -0.355588 -0.287676  0.406542  1.000000   0.301543
# MRI_Count    0.498369  0.413105  0.568237 -0.076875  0.301543   1.000000
# Unnamed: 7        NaN       NaN       NaN       NaN       NaN        NaN
# Promedio     0.998956  0.946878  0.931633 -0.275284 -0.350501   0.512854
# MRI          0.498369  0.413105  0.568237 -0.076875  0.301543   1.000000
# Unnamed: 10       NaN       NaN       NaN       NaN       NaN        NaN
# Unnamed: 11       NaN       NaN       NaN       NaN       NaN        NaN
#
#              Unnamed: 7  Promedio       MRI  Unnamed: 10  Unnamed: 11
# FSIQ                NaN  0.998956  0.498369          NaN          NaN
# VIQ                 NaN  0.946878  0.413105          NaN          NaN
# PIQ                 NaN  0.931633  0.568237          NaN          NaN
# Weight              NaN -0.275284 -0.076875          NaN          NaN
# Height              NaN -0.350501  0.301543          NaN          NaN
# MRI_Count           NaN  0.512854  1.000000          NaN          NaN
# Unnamed: 7          NaN       NaN       NaN          NaN          NaN
# Promedio            NaN  1.000000  0.512854          NaN          NaN
# MRI                 NaN  0.512854  1.000000          NaN          NaN
# Unnamed: 10         NaN       NaN       NaN          NaN          NaN
# Unnamed: 11         NaN       NaN       NaN          NaN          NaN

# %%
import seaborn as sns
womenNoGenderDf = womenDf.drop('Gender', axis=1)
menNoGenderDf = menDf.drop('Gender', axis=1)
womenNoGenderDf = womenNoGenderDf[womenNoGenderDf.columns].astype(float)
menNoGenderDf = menNoGenderDf[menNoGenderDf.columns].astype(float)

# %%
wcorr = womenNoGenderDf.corr()
sns.heatmap(wcorr)
# Out:
# <AxesSubplot:>

# %%
mcorr = menNoGenderDf.corr()
sns.heatmap(mcorr)
# Out:
# <AxesSubplot:>
